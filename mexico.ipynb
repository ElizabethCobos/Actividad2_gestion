# %%
#Importamos Librerias
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Cargamos el archivo diamonds.csv
df = pd.read_csv('Mexico.csv')
df
# Out:
#                 id                                               name  \
# 0     5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 1     1.551198e+07                                 La casa de Abraham
# 2     3.477645e+07  ‚òÖ The attic ‚òÖ Panoramic garden 10 min Citi...
# 3     4.576710e+07  BONITO DEPARTAMENTO NUEVO  LOMAS DE  TECAMACHALCO
# 4     8.328050e+05      ROOMS CASA INDIGO WITH TERRACE AT CITY CENTER
# ...            ...                                                ...
# 8072  5.950800e+17  üåéHABITACI√ìN PRIVADA A 10 MINUTOS DEL AEROP...
# 8073  4.023676e+07  BONITA HABITACI√ìN AMUEBLADA Y EQUIPADA COLCH√...
# 8074  1.850579e+07     Excelente habitaci√≥n privada en la mejor zona
# 8075  5.168697e+07       Hostal 14 .3 \nhabitaci√≥n privada con ba√±o
# 8076  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
#
#         host_id           host_name  neighbourhood_group  \
# 0     424060909  Maria Carmen Marta                  NaN
# 1      93364273             Abraham                  NaN
# 2       2954577    Lazaro Alejandro                  NaN
# 3     371036285                Luis                  NaN
# 4       3777702             Abraham                  NaN
# ...         ...                 ...                  ...
# 8072  441357788               Jorge                  NaN
# 8073  169606297              Soraya                  NaN
# 8074   75820963               Aylin                  NaN
# 8075  395371158            Gabriela                  NaN
# 8076   47070934           Alejandra                  NaN
#
#               neighbourhood   latitude  longitude     room_type  price  \
# 0     Cuajimalpa de Morelos  19.395126 -99.277374  Private room    752
# 1            Miguel Hidalgo  19.410950 -99.244180  Private room    800
# 2            Miguel Hidalgo  19.426410 -99.225910  Private room   1779
# 3            Miguel Hidalgo  19.419470 -99.240630  Private room    500
# 4               Cuauht√©moc  19.442620 -99.145660  Private room    444
# ...                     ...        ...        ...           ...    ...
# 8072      Gustavo A. Madero  19.470540 -99.052970  Private room    330
# 8073         Miguel Hidalgo  19.406220 -99.251820  Private room    333
# 8074  Cuajimalpa de Morelos  19.405220 -99.278260  Private room    490
# 8075      Gustavo A. Madero  19.484990 -99.060730  Private room    210
# 8076           Azcapotzalco  19.501490 -99.228090  Private room    250
#
#       minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                  1                  0         NaN                NaN
# 1                  1                  1    19/03/18               0.02
# 2                  1                  5    14/03/22               0.14
# 3                  7                  0         NaN                NaN
# 4                  1                125    26/01/22               1.08
# ...              ...                ...         ...                ...
# 8072               2                  4    28/05/22               1.54
# 8073               3                  0         NaN                NaN
# 8074               2                  2    01/11/17               0.03
# 8075               1                  6    05/12/21               0.64
# 8076               6                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                                  1               365                      0
# 1                                  1               179                      0
# 2                                  4               222                      1
# 3                                  1               365                      0
# 4                                  6               288                      2
# ...                              ...               ...                    ...
# 8072                               3               365                      4
# 8073                               1               363                      0
# 8074                               1               365                      0
# 8075                               6               365                      6
# 8076                               1               364                      0
#
#       license
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 8072      NaN
# 8073      NaN
# 8074      NaN
# 8075      NaN
# 8076      NaN
#
# [8077 rows x 18 columns]
